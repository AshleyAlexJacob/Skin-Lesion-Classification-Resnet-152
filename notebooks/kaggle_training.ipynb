# %% [markdown]
# # Skin Lesion Classification - Kaggle Training
#
# This notebook will:
# 1. Clone the project repository.
# 2. Set up the working directory and install requirements.
# 3. Copy the dataset from Kaggle's `/kaggle/input` to the local `data/raw/archive`.
# 4. Run the data preprocessing pipeline.
# 5. Run the model training pipeline.

# %%
# 1. Clone the repository
# !git clone https://github.com/AshleyAlexJacob/Skin-Lesion-Classification-Resnet-152.git

# %%
# 2. Change working directory and install requirements
import os
os.chdir('/kaggle/working/Skin-Lesion-Classification-Resnet-152')
# !pip install -r requirements.txt

# %%
# 3. Prepare data directory and copy dataset
# WARNING: Make sure to attach the HAM10000 dataset to your Kaggle Notebook.
# Depending on the name of the dataset you attached, you may need to update the source path below.
# !mkdir -p data/raw/archive
# !cp -r /kaggle/input/skin-cancer-mnist-ham10000/* data/raw/archive/

# %%
# 4. Run data preprocessing
# This will merge part_1 and part_2 and organize images into subfolders by class.
# !python -m src.pipelines.data_preprocessing

# %%
# 5. Start the training pipeline
# !python -m src.pipelines.model_training
